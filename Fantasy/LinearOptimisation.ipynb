# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
sns.set_style('whitegrid')
pd.options.mode.chained_assignment = None
pd.set_option('display.max_columns', 100)

# %%
# Read the CSV into a Pandas DataFrame
fantasy_df = pd.read_csv("../Data/testdata.csv")

# Print the first five rows of data to the screen
fantasy_df.head()
# Out:
#     Player_name        Date Team  Opp  H/A  GTime(ET)  Team pts  Opp pts  Win  \
# 0  Drew Eubanks   1/10/2020  sas  mem    0       20.0       121      134    0
# 1  Drew Eubanks    1/8/2020  sas  bos    1       19.0       129      114    1
# 2  Drew Eubanks  12/28/2019  sas  det    1       20.5       136      109    1
# 3  Drew Eubanks   12/3/2019  sas  hou    1       20.5       135      133    1
# 4  Drew Eubanks   12/1/2019  sas  det    0       17.0        98      132    0
#
#    Start  Mins_played   FDP  DoubleD  TripleD  FD_Sal  FD pos    ADI   VMI  \
# 0      0     1.766667   2.0        0        0    3500       5  65.06  0.25
# 1      0     2.266667   2.0        0        0    3500       5  66.39 -1.99
# 2      0     3.116667   9.6        0        0    3500       5  62.96  0.90
# 3      0     6.266667   4.9        0        0    3600       5  64.01 -0.87
# 4      0    21.816667  21.1        0        0    3500       5  61.27  2.79
#
# ...

# %%
fantasy_df = fantasy_df.rename(columns={'FD pos':'FD_pos'})
fantasy_df['Player_name'] = fantasy_df['Player_name'].replace(' ', '_', regex=True)
fantasy_df
# Out:
#                Player_name        Date Team  Opp  H/A  GTime(ET)  Team pts  \
# 0             Drew_Eubanks   1/10/2020  sas  mem    0       20.0       121
# 1             Drew_Eubanks    1/8/2020  sas  bos    1       19.0       129
# 2             Drew_Eubanks  12/28/2019  sas  det    1       20.5       136
# 3             Drew_Eubanks   12/3/2019  sas  hou    1       20.5       135
# 4             Drew_Eubanks   12/1/2019  sas  det    0       17.0        98
# ...                    ...         ...  ...  ...  ...        ...       ...
# 15634  Willie_Cauley-Stein   11/6/2019  gsw  hou    0       19.5       112
# 15635  Willie_Cauley-Stein   11/4/2019  gsw  por    1       22.5       127
# 15636  Willie_Cauley-Stein   11/2/2019  gsw  cha    0       20.5        87
# 15637  Willie_Cauley-Stein   11/1/2019  gsw  sas    0       22.5       110
# 15638  Willie_Cauley-Stein  10/30/2019  gsw  pho    0       22.5       110
#
# ...

# %%
fantasy_df = fantasy_df.dropna()
fantasy_df
# Out:
#                Player_name        Date Team  Opp  H/A  GTime(ET)  Team pts  \
# 0             Drew_Eubanks   1/10/2020  sas  mem    0       20.0       121
# 1             Drew_Eubanks    1/8/2020  sas  bos    1       19.0       129
# 2             Drew_Eubanks  12/28/2019  sas  det    1       20.5       136
# 3             Drew_Eubanks   12/3/2019  sas  hou    1       20.5       135
# 4             Drew_Eubanks   12/1/2019  sas  det    0       17.0        98
# ...                    ...         ...  ...  ...  ...        ...       ...
# 15634  Willie_Cauley-Stein   11/6/2019  gsw  hou    0       19.5       112
# 15635  Willie_Cauley-Stein   11/4/2019  gsw  por    1       22.5       127
# 15636  Willie_Cauley-Stein   11/2/2019  gsw  cha    0       20.5        87
# 15637  Willie_Cauley-Stein   11/1/2019  gsw  sas    0       22.5       110
# 15638  Willie_Cauley-Stein  10/30/2019  gsw  pho    0       22.5       110
#
# ...

# %%
fantasy_df.columns
# Out:
# Index(['Player_name', 'Date', 'Team', 'Opp', 'H/A', 'GTime(ET)', 'Team pts',
#        'Opp pts', 'Win', 'Start', 'Mins_played', 'FDP', 'DoubleD', 'TripleD',
#        'FD_Sal', 'FD_pos', 'ADI', 'VMI', 'pt', 'rb', 'as', 'st', 'bl', 'to',
#        '3pts', 'FGM', 'FGA', 'FG%', 'FTM', 'FTA', 'FT%'],
#       dtype='object')

# %%
fantasy_df.corr()['FDP']
# Out:
# H/A            0.084879
# GTime(ET)     -0.005039
# Team pts       0.112638
# Opp pts        0.000290
# Win            0.084879
# Start          0.534421
# Mins_played    0.783234
# FDP            1.000000
# DoubleD        0.491511
# TripleD        0.183441
# FD_Sal         0.714163
# FD_pos         0.024494
# ADI            0.012402
# VMI           -0.005153
# pt             0.877306
# rb             0.668490
# as             0.614246
# st             0.471333
# bl             0.372363
# to             0.410570
# 3pts           0.474234
# FGM            0.514324
# FGA            0.089181
# FG%            0.295843
# FTM            0.526137
# FTA            0.517472
# FT%            0.341152
# Name: FDP, dtype: float64

# %%
to_drop = ['H/A', 'GTime(ET)', 'Team pts', 'Opp pts', 'Win', 'TripleD','ADI', 'VMI', 'FGA', 'FG%', 'FTA', 'FT%']

# %%
fantasy_df.pivot_table(index='FD_pos', values='FDP', aggfunc=np.mean)
# Out:
#               FDP
# FD_pos
# 1       21.870038
# 2       20.579889
# 3       20.246138
# 4       20.569665
# 5       23.816737

# %%
fantasy_df.pivot_table(index='FD_pos', values='FDP', aggfunc=np.median)
# Out:
#           FDP
# FD_pos
# 1       19.80
# 2       18.30
# 3       18.45
# 4       19.20
# 5       22.00

# %%
fantasy_df.drop(to_drop, axis=1, inplace = True)
fantasy_df
# Out:
#                Player_name        Date Team  Opp  Start  Mins_played   FDP  \
# 0             Drew_Eubanks   1/10/2020  sas  mem      0     1.766667   2.0
# 1             Drew_Eubanks    1/8/2020  sas  bos      0     2.266667   2.0
# 2             Drew_Eubanks  12/28/2019  sas  det      0     3.116667   9.6
# 3             Drew_Eubanks   12/3/2019  sas  hou      0     6.266667   4.9
# 4             Drew_Eubanks   12/1/2019  sas  det      0    21.816667  21.1
# ...                    ...         ...  ...  ...    ...          ...   ...
# 15634  Willie_Cauley-Stein   11/6/2019  gsw  hou      1    19.983333  11.8
# 15635  Willie_Cauley-Stein   11/4/2019  gsw  por      1    15.500000  21.6
# 15636  Willie_Cauley-Stein   11/2/2019  gsw  cha      1    21.216667  26.6
# 15637  Willie_Cauley-Stein   11/1/2019  gsw  sas      1    17.016667  15.0
# 15638  Willie_Cauley-Stein  10/30/2019  gsw  pho      0    12.316667  22.5
#
# ...

# %%
fantasy_df['FD_pos'] = fantasy_df['FD_pos'].replace([1,2,3,4,5],['PG', 'SG', 'SF', 'PF', 'C'])
fantasy_df
# Out:
#                Player_name        Date Team  Opp  Start  Mins_played   FDP  \
# 0             Drew_Eubanks   1/10/2020  sas  mem      0     1.766667   2.0
# 1             Drew_Eubanks    1/8/2020  sas  bos      0     2.266667   2.0
# 2             Drew_Eubanks  12/28/2019  sas  det      0     3.116667   9.6
# 3             Drew_Eubanks   12/3/2019  sas  hou      0     6.266667   4.9
# 4             Drew_Eubanks   12/1/2019  sas  det      0    21.816667  21.1
# ...                    ...         ...  ...  ...    ...          ...   ...
# 15634  Willie_Cauley-Stein   11/6/2019  gsw  hou      1    19.983333  11.8
# 15635  Willie_Cauley-Stein   11/4/2019  gsw  por      1    15.500000  21.6
# 15636  Willie_Cauley-Stein   11/2/2019  gsw  cha      1    21.216667  26.6
# 15637  Willie_Cauley-Stein   11/1/2019  gsw  sas      1    17.016667  15.0
# 15638  Willie_Cauley-Stein  10/30/2019  gsw  pho      0    12.316667  22.5
#
# ...

# %% [markdown]
# # Kernel Density Analysis

# %%
f = plt.figure(figsize=(16,9))

ax1 = f.add_subplot(2,3,1)
ax2 = f.add_subplot(2,3,2,sharex=ax1, sharey=ax1)
ax3 = f.add_subplot(2,3,3,sharex=ax1, sharey=ax1)
ax4 = f.add_subplot(2,3,4,sharex=ax1, sharey=ax1)
ax5 = f.add_subplot(2,3,5,sharex=ax1, sharey=ax1)

ax1.set_title('Point Guard (PG)')
sns.distplot(fantasy_df[fantasy_df.FD_pos=='PG'].FDP, label='PG',ax=ax1)
ax1.axvline(np.mean(fantasy_df[fantasy_df.FD_pos=='PG'].FDP),color='red', label='mean')

ax2.set_title('Shooting Guard (SG)')
sns.distplot(fantasy_df[fantasy_df.FD_pos=='SG'].FDP, label='SG',ax=ax2)
ax2.axvline(np.mean(fantasy_df[fantasy_df.FD_pos=='SG'].FDP),color='red', label='mean')

ax3.set_title('Small Forward (SF)')
sns.distplot(fantasy_df[fantasy_df.FD_pos=='SF'].FDP, label='SF',ax=ax3)
ax3.axvline(np.mean(fantasy_df[fantasy_df.FD_pos=='SF'].FDP),color='red', label='mean')

ax4.set_title('Power Forward (PF)')
sns.distplot(fantasy_df[fantasy_df.FD_pos=='PF'].FDP, label='PF',ax=ax4)
ax4.axvline(np.mean(fantasy_df[fantasy_df.FD_pos=='PF'].FDP),color='red', label='mean')

ax5.set_title('Center (C)')
sns.distplot(fantasy_df[fantasy_df.FD_pos=='C'].FDP, label='C',ax=ax5)
ax5.axvline(np.mean(fantasy_df[fantasy_df.FD_pos=='C'].FDP),color='red', label='mean')

plt.show()

# %%
fantasy_df.columns
# Out:
# Index(['Player_name', 'Date', 'Team', 'Opp', 'Start', 'Mins_played', 'FDP',
#        'DoubleD', 'FD_Sal', 'FD_pos', 'pt', 'rb', 'as', 'st', 'bl', 'to',
#        '3pts', 'FGM', 'FTM'],
#       dtype='object')

# %%
fantasy_df[fantasy_df['Player_name']=='Frank_Mason_III']
# Out:
#         Player_name        Date Team  Opp  Start  Mins_played  FDP  DoubleD  \
# 10  Frank_Mason_III  12/22/2019  mil  ind      0     4.766667  3.7        0
# 11  Frank_Mason_III  12/14/2019  mil  cle      0     2.766667  6.2        0
# 12  Frank_Mason_III  11/30/2019  mil  cha      0    10.033333  7.0        0
# 13  Frank_Mason_III  11/29/2019  mil  cle      0     0.150000  0.0        0
#
#     FD_Sal FD_pos  pt  rb  as  st  bl  to  3pts  FGM  FTM
# 10    3500     PG   1   1   1   0   0   0     0    0    1
# 11    3500     PG   0   1   2   1   0   1     0    0    0
# 12    3500     PG   4   0   2   0   0   0     1    1    1
# 13    3500     PG   0   0   0   0   0   0     0    0    0

# %% [markdown]
# # LINEAR MODELING

# %%
from pulp import *
prob = pulp.LpProblem('FantasyTeam', pulp.LpMaximize)

# %%
decision_variables = []
for rownum, row in fantasy_df.iterrows():
    variable = str('x' + str(rownum))
    variable = pulp.LpVariable(str(variable), lowBound = 0, upBound = 1, cat= 'Integer') #make variables binary
    decision_variables.append(variable)

print ("Total number of decision_variables: " + str(len(decision_variables)))
# Out:
# Total number of decision_variables: 15639

# %% [markdown]
# #Optimisation Function

# %%
total_points = ""
for rownum, row in fantasy_df.iterrows():
    for i, player in enumerate(decision_variables):
        if rownum == i:
            formula = row['FDP']*player
            total_points += formula

prob += total_points
print ("Optimization function: " + str(total_points))
# Out:
# Optimization function: 2.0*x0 + 2.0*x1 + 3.7*x10 + 20.9*x100 + 18.9*x1000 + 26.3*x10000 + 31.7*x10001 + 20.0*x10002 + 36.4*x10003 + 21.8*x10004 + 32.9*x10005 + 30.5*x10006 + 39.5*x10007 + 23.6*x10008 + 23.8*x10009 + 39.2*x1001 + 22.7*x10010 + 26.5*x10011 + 22.2*x10012 + 29.0*x10013 + 34.4*x10014 + x10015 + 7.0*x10016 + 3.5*x10018 + 11.7*x10019 + 23.9*x1002 + 2.0*x10020 + 4.2*x10021 + 4.2*x10022 + 3.2*x10023 + 3.2*x10024 + 6.7*x10025 + 3.2*x10026 + 8.5*x10027 + 25.0*x10028 + 21.2*x10029 + 29.6*x1003 + 6.5*x10030 + 4.4*x10031 + 1.5*x10032 + 4.2*x10033 + 28.3*x10034 + 12.4*x10035 + 11.3*x10036 + 5.7*x10037 + 3.5*x10038 + 3.0*x10039 + 39.9*x1004 + 19.7*x10040 + 12.7*x10041 + 18.2*x10042 + 12.2*x10043 + 42.4*x10044 + 27.4*x10045 + 11.2*x10046 + 19.3*x10047 + 20.5*x10048 + 17.4*x10049 + 21.5*x1005 + 29.5*x10050 + 22.4*x10051 + 17.1*x10052 + 33.9*x10053 + 29.8*x10054 + 18.5*x10055 + 20.7*x10056 + 14.7*x10057 + 13.6*x10058 + 27.2*x10059 + 37.6*x1006 + 26.8*x10060 + 11.0*x10061 + 43.7*x10062 
# ...

# %% [markdown]
# #Cash Constraint

# %%
avail_cash = 60000
total_cost = ""
for rownum, row in fantasy_df.iterrows():
    for i, player in enumerate(decision_variables):
        if rownum == i:
            formula = row['FD_Sal']*player
            total_cost += formula

prob += (total_cost <= avail_cash)

# %% [markdown]
# # Player Constraints

# %% [markdown]
# #Point Guard

# %%
avail_PG = 2
total_PG = ""
for rownum, row in fantasy_df.iterrows():
    for i, player in enumerate(decision_variables):
        if rownum == i:
            if row['FD_pos'] == 'PG':
                formula = 1*player
                total_PG += formula
prob += (total_PG == avail_PG)
print(total_PG)
# Out:
# x10 + x1000 + x1001 + x1002 + x10024 + x10025 + x10026 + x10027 + x10028 + x10029 + x1003 + x10030 + x10031 + x10032 + x10033 + x10034 + x10035 + x10036 + x10037 + x10038 + x10039 + x1004 + x10040 + x10041 + x10042 + x1005 + x1006 + x1007 + x1008 + x1009 + x101 + x1010 + x1011 + x1012 + x10122 + x10123 + x10124 + x10125 + x10126 + x10127 + x10128 + x10129 + x1013 + x10130 + x10131 + x10132 + x10133 + x10134 + x10135 + x10136 + x10137 + x10138 + x10139 + x1014 + x10140 + x10141 + x10142 + x10143 + x10144 + x10145 + x10146 + x10147 + x10148 + x10149 + x1015 + x10150 + x10151 + x10152 + x10153 + x10154 + x10155 + x10156 + x10157 + x10158 + x10159 + x1016 + x10160 + x10161 + x10162 + x10163 + x10164 + x10165 + x10166 + x10167 + x10168 + x10169 + x1017 + x10170 + x1018 + x1019 + x102 + x1020 + x1021 + x1022 + x103 + x10326 + x10327 + x10328 + x10329 + x10330 + x10331 + x10332 + x10333 + x10334 + x10335 + x10336 + x10337 + x10338 + x10339 + x10340 + x10341 + x10342 + x10343 + x10344 + x103
# ...

# %% [markdown]
# #Shooting Guard

# %%
avail_SG = 2
total_SG = ""
for rownum, row in fantasy_df.iterrows():
    for i, player in enumerate(decision_variables):
        if rownum == i:
            if row['FD_pos'] == 'SG':
                formula = 1*player
                total_SG += formula
prob += (total_SG == avail_SG)
print(total_SG)
# Out:
# x10015 + x10016 + x10017 + x10018 + x10019 + x10020 + x10021 + x10022 + x10023 + x10043 + x10044 + x10045 + x10046 + x10047 + x10048 + x10049 + x10050 + x10051 + x10052 + x10053 + x10054 + x10055 + x10056 + x10057 + x10058 + x10059 + x10060 + x10061 + x10062 + x10063 + x10064 + x10065 + x10066 + x10067 + x10068 + x10069 + x10070 + x10071 + x10072 + x10073 + x10074 + x10075 + x10076 + x10077 + x10078 + x10079 + x10080 + x10081 + x10082 + x10083 + x10084 + x10085 + x10086 + x10087 + x10088 + x10089 + x10090 + x10091 + x10092 + x10093 + x10094 + x10095 + x10096 + x10097 + x10098 + x10099 + x10100 + x10101 + x10102 + x10103 + x10104 + x10105 + x10106 + x10107 + x10108 + x10109 + x10110 + x10111 + x10112 + x10113 + x10114 + x10115 + x10116 + x10117 + x10118 + x10119 + x10368 + x10369 + x10370 + x10371 + x10372 + x10509 + x10510 + x10511 + x10512 + x10513 + x10514 + x10515 + x10516 + x10517 + x10518 + x10519 + x10520 + x10521 + x10522 + x10523 + x10524 + x10525 + x10526 + x10527 + x10528 +
# ...

# %% [markdown]
# #Small Forward

# %%
avail_SF = 2
total_SF = ""
for rownum, row in fantasy_df.iterrows():
    for i, player in enumerate(decision_variables):
        if rownum == i:
            if row['FD_pos'] == 'SF':
                formula = 1*player
                total_SF += formula
prob += (total_SF == avail_SF)
print(total_SF)
# Out:
# x10000 + x10001 + x10002 + x10003 + x10004 + x10005 + x10006 + x10007 + x10008 + x10009 + x10010 + x10011 + x10012 + x10013 + x10014 + x10120 + x10121 + x1023 + x1024 + x1025 + x1026 + x10266 + x10267 + x10268 + x10269 + x1027 + x10270 + x10271 + x10272 + x10273 + x10274 + x1028 + x1029 + x1030 + x1031 + x1032 + x1033 + x1034 + x1035 + x1036 + x1037 + x1038 + x1039 + x1040 + x1041 + x1042 + x1043 + x1044 + x1045 + x1046 + x1047 + x1048 + x1049 + x1050 + x1051 + x1052 + x1053 + x1054 + x1055 + x1056 + x1057 + x1058 + x1059 + x1060 + x1061 + x1062 + x1063 + x1064 + x10645 + x10646 + x10647 + x10648 + x10649 + x1065 + x10650 + x10651 + x10652 + x10653 + x10654 + x10655 + x10656 + x10657 + x10658 + x10659 + x1066 + x10660 + x10661 + x10662 + x10663 + x1067 + x1068 + x1069 + x1070 + x1071 + x1072 + x1073 + x1074 + x1075 + x1076 + x1077 + x1078 + x1079 + x1080 + x1081 + x1082 + x1083 + x1084 + x1085 + x1086 + x1087 + x1088 + x1089 + x1090 + x10964 + x10965 + x10966 + x10967 + x10968 + x109
# ...

# %% [markdown]
# #Power Forward

# %%
avail_PF = 2
total_PF = ""
for rownum, row in fantasy_df.iterrows():
    for i, player in enumerate(decision_variables):
        if rownum == i:
            if row['FD_pos'] == 'PF':
                formula = 1*player
                total_PF += formula
prob += (total_PF == avail_PF)
print(total_PF)
# Out:
# x100 + x10171 + x10172 + x10173 + x10174 + x10175 + x10176 + x10177 + x10178 + x10179 + x10180 + x10181 + x10182 + x10183 + x10184 + x10185 + x10186 + x10187 + x10188 + x10189 + x10190 + x10191 + x10192 + x10193 + x10194 + x10195 + x10196 + x10197 + x10198 + x10199 + x10200 + x10201 + x10202 + x10203 + x10204 + x10205 + x10206 + x10207 + x10208 + x10209 + x10210 + x10211 + x10212 + x10213 + x10214 + x10215 + x10216 + x10217 + x10218 + x10219 + x10220 + x10221 + x10222 + x10223 + x10224 + x10225 + x10226 + x10227 + x10228 + x10229 + x10230 + x10231 + x10232 + x10233 + x10234 + x10235 + x10236 + x10237 + x10238 + x10239 + x10240 + x10241 + x10242 + x10243 + x10244 + x10245 + x10246 + x10247 + x10248 + x10249 + x10250 + x10251 + x10252 + x10253 + x10254 + x10255 + x10256 + x10257 + x10258 + x10259 + x10260 + x10261 + x10262 + x10263 + x10264 + x10265 + x10275 + x10276 + x10277 + x10278 + x10279 + x10280 + x10281 + x10282 + x10283 + x10284 + x10285 + x10286 + x10287 + x10288 + x10289 + x
# ...

# %% [markdown]
# #Center

# %%
avail_C = 1
total_C = ""
for rownum, row in fantasy_df.iterrows():
    for i, player in enumerate(decision_variables):
        if rownum == i:
            if row['FD_pos'] == 'C':
                formula = 1*player
                total_C += formula
prob += (total_C == avail_C)
print(total_C)
# Out:
# x0 + x1 + x10461 + x10462 + x10463 + x10464 + x10465 + x10466 + x10467 + x10468 + x10469 + x10470 + x10471 + x10472 + x10473 + x10474 + x10475 + x10476 + x10477 + x10478 + x10479 + x10480 + x10481 + x10482 + x10483 + x10484 + x10485 + x10486 + x10487 + x10488 + x10489 + x10490 + x10491 + x10492 + x10493 + x10494 + x10495 + x10496 + x10497 + x10498 + x10499 + x10500 + x10501 + x10502 + x10503 + x10504 + x10505 + x10506 + x10507 + x10508 + x1091 + x1092 + x1093 + x1094 + x1095 + x1096 + x1097 + x1098 + x1099 + x1100 + x1101 + x1102 + x1103 + x1104 + x11047 + x11048 + x11049 + x1105 + x11050 + x11051 + x11052 + x11053 + x11054 + x11055 + x11056 + x11057 + x11058 + x11059 + x1106 + x11060 + x11061 + x11062 + x11063 + x11064 + x11065 + x11066 + x11067 + x11068 + x11069 + x1107 + x11070 + x11071 + x11072 + x11073 + x11074 + x11075 + x11076 + x11077 + x11078 + x11079 + x1108 + x11080 + x11081 + x11082 + x11083 + x11084 + x11085 + x11086 + x11087 + x11088 + x11089 + x1109 + x11090 + x11091 +
# ...

# %% [markdown]
# # Solving the problem

# %%
prob.writeLP('FantasyTeam.lp')
optimization_result = prob.solve()
assert optimization_result == pulp.LpStatusOptimal
print("Status:", LpStatus[prob.status])
print("Optimal Solution to the problem: ", value(prob.objective))
print ("Individual decision_variables: ")
for v in prob.variables():
	print(v.name, "=", v.varValue)
# Out:
# Status: Optimal
# Optimal Solution to the problem:  None
# Individual decision_variables:
# __dummy = None
# x0 = 0.0
# x1 = 0.0
# x10 = 0.0
# x100 = 0.0
# x1000 = 0.0
# x10000 = 0.0
# x10001 = 0.0
# x10002 = 0.0
# x10003 = 0.0
# x10004 = 0.0
# x10005 = 0.0
# x10006 = 0.0
# x10007 = 0.0
# x10008 = 0.0
# x10009 = 0.0
# x1001 = 0.0
# x10010 = 0.0
# x10011 = 0.0
# x10012 = 0.0
# x10013 = 0.0
# x10014 = 0.0
# x10015 = 0.0
# x10016 = 0.0
# x10017 = 0.0
# x10018 = 0.0
# x10019 = 0.0
# x1002 = 0.0
# x10020 = 0.0
# x10021 = 0.0
# x10022 = 0.0
# x10023 = 0.0
# x10024 = 0.0
# x10025 = 0.0
# x10026 = 0.0
# x10027 = 0.0
# x10028 = 0.0
# x10029 = 0.0
# x1003 = 0.0
# x10030 = 0.0
# x10031 = 0.0
# x10032 = 0.0
# x10033 = 0.0
# x10034 = 0.0
# x10035 = 0.0
# x10036 = 0.0
# x10037 = 0.0
# x10038 = 0.0
# x10039 = 0.0
# x1004 = 0.0
# x10040 = 0.0
# x10041 = 0.0
# x10042 = 0.0
# x10043 = 0.0
# x10044 = 0.0
# x10045 = 0.0
# x10046 = 0.0
# x10047 = 0.0
# x10048 = 0.0
# x10049 = 0.0
# x1005 = 0.0
# ...

# %% [markdown]
# # Results

# %%
variable_name = []
variable_value = []

for v in prob.variables():
    variable_name.append(v.name)
    variable_value.append(v.varValue)

df = pd.DataFrame({'variable': variable_name, 'value': variable_value})
df = df.dropna()
df
# Out:
#       variable  value
# 1           x0    0.0
# 2           x1    0.0
# 3          x10    0.0
# 4         x100    0.0
# 5        x1000    0.0
# ...        ...    ...
# 15635    x9995    0.0
# 15636    x9996    0.0
# 15637    x9997    0.0
# 15638    x9998    0.0
# 15639    x9999    0.0
#
# [15639 rows x 2 columns]

# %%
df.to_csv("optimization.csv")

# %%
for rownum, row in df.iterrows():
    value = re.findall(r'\d+', row['variable'])
    df.loc[rownum, 'variable'] = int(value[0])

df = df.sort_values(df.variable)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-ece45f3b1383> in <module>
#       1 for rownum, row in df.iterrows():
# ----> 2     value = re.findall(r'^\d+', row['variable'])
#       3     df.loc[rownum, 'variable'] = int(value[0])
#       4
#       5 df = df.sort_values(df.variable)
#
# ~\Anaconda3\envs\pythondata\lib\re.py in findall(pattern, string, flags)
#     221
#     222     Empty matches are included in the result."""
# --> 223     return _compile(pattern, flags).findall(string)
#     224
#     225 def finditer(pattern, string, flags=0):
#
# TypeError: cannot use a string pattern on a bytes-like object

# %%
#append results
for rownum, row in fantasy_df.iterrows():
    for results_rownum, results_row in df.iterrows():
        if rownum == results_row['variable']:
            fantasy_df.loc[rownum, 'decision'] = results_row['value']

fantasy_df[fantasy_df.decision==1].FD_Sal.sum()
fantasy_df[fantasy_df.decision==1].FDP.sum()
fantasy_df[fantasy_df.decision==1].sort_values('FD_pos').head(10)
# Out:
# Empty DataFrame
# Columns: [Player_name, Date, Team, Opp, H/A, GTime(ET), Team pts, Opp pts, Win, Start, Mins_played, FDP, DoubleD, TripleD, FD_Sal, FD_pos, ADI, VMI, pt, rb, as, st, bl, to, 3pts, FGM, FGA, FG%, FTM, FTA, FT%, decision]
# Index: []
