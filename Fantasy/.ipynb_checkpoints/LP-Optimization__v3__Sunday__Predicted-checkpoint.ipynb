# %%
# %matplotlib inline
import glob
import matplotlib.pyplot as plt
import pandas as pd
import pulp
import csv


pd.set_option('display.width', 1000)

# %%
# create dataframe of past salaries and past performance
fantasy_full = pd.read_csv("../Data/final.csv")

# create dataframe of past salaries and past performance
fantasyDay = pd.read_csv("../Data/20200209__players.csv")

# Print the first five rows of data to the screen
fantasy_full.head()
# Out:
#                Name   GID Team  Opp  Home  NewGameFDP  LastFDP  AvgFDP  AvgPTS  LastPT  ...  LastTOV        Date  Last3GameAvgFDP  Last3GameAvgMIN  Last3GameAvgPTS  position      Rank  TeamStdFDP  TeamAvgFDP  TeamMaxFDP
# 0    Louis Williams  3816  lac  gsw     0        40.6     38.5    38.5    21.0      21  ...        2  2019-10-23             38.5        36.733333             21.0        SG  advanced   11.726994   30.028571        47.7
# 1  Montrezl Harrell  4857  lac  gsw     0        23.7     34.4    34.4    17.0      17  ...        3  2019-10-23             34.4        38.366667             17.0         C  advanced   11.726994   30.028571        47.7
# 2  Patrick Beverley  4234  lac  gsw     0        27.3     24.0    24.0     2.0       2  ...        2  2019-10-23             24.0        31.366667              2.0        PG   average   11.726994   30.028571        47.7
# 3    Andre Drummond  4489  det  atl     1        49.4     81.6    81.6    32.0      32  ...        2  2019-10-23             81.6        40.800000             32.0         C       top   23.544654   27.325000        81.6
# 4      Derrick Rose  4073  det  atl     1        29.7     29.9    29.9    18.0      18  ...        4  2019-10-23             29.9        26.583333             18.0        SG   average   23.544654   27.325000        81.6
#
# [5 rows x 34 columns]

# %%
fantasyDay.columns
# Out:
# Index(['Name', 'Last', 'First', 'Player_Name', 'GID', 'Date', 'Starter', 'FD Pts', 'FD Salary', 'Pos', 'Team', 'H/A', 'Oppt', 'Team Score', 'Oppt Score', 'Minutes', 'Stat line'], dtype='object')

# %%
fantasyDay = fantasyDay[['Player_Name', 'FD_Pts', 'FD_Sal', 'Pos', 'Date']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-367d0dcd4d28> in <module>
# ----> 1 fantasyDay = fantasyDay[['Player_Name', 'FD_Pts', 'FD_Sal', 'Pos', 'Date']]
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2999             if is_iterator(key):
#    3000                 key = list(key)
# -> 3001             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    3002
#    3003         # take() does not accept boolean indexers
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1285                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1286         else:
#    1287             try:
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1090
#    1091         self._validate_read_indexer(
# -> 1092             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1093         )
#    1094         return keyarr, indexer
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1183             if not (self.name == "loc" and not raise_missing):
#    1184                 not_found = list(set(key) - set(ax))
# -> 1185                 raise KeyError("{} not in index".format(not_found))
#    1186
#    1187             # we skip the warning on Categorical/Interval
#
# KeyError: "['FD_Sal', 'FD_Pts'] not in index"

# %%
fantasyDay = fantasyDay.rename(columns={'Player_Name':'Name'})

# %%
fantasy_df = pd.merge(fantasy_full,fantasyDay, on="Name", how="inner")
fantasy_df
# Out:
#                   Name   GID Team  Opp  Home  NewGameFDP  LastFDP     AvgFDP     AvgPTS  LastPT  ...  Last3GameAvgPTS  position      Rank  TeamStdFDP  TeamAvgFDP  TeamMaxFDP  FD_Pts  FD_Sal  Pos    Date_y
# 0       Louis Williams  3816  lac  gsw     0        40.6     38.5  38.500000  21.000000      21  ...        21.000000        SG  advanced   11.726994   30.028571   47.700000    22.7  5400.0   SG  20200208
# 1     Montrezl Harrell  4857  lac  gsw     0        23.7     34.4  34.400000  17.000000      17  ...        17.000000         C  advanced   11.726994   30.028571   47.700000    14.2  5800.0    C  20200208
# 2     Patrick Beverley  4234  lac  gsw     0        27.3     24.0  24.000000   2.000000       2  ...         2.000000        PG   average   11.726994   30.028571   47.700000     0.0  4800.0   PG  20200208
# 3         Derrick Rose  4073  det  atl     1        29.7     29.9  29.900000  18.000000      18  ...        18.000000        SG   average   23.544654   27.325000   81.600000     0.0  6900.0   PG  20200208
# 4    Langston Galloway  4735  det  atl     1        21.1     12.8  12.800000   5.000000       5  ...         5.000000        SG  belowAvg   23.544654   27.325000   81.600000     7.4  3900.0   SG  20200208
# ..                 ...   ...  ...  ...   ...         ...      ...        ...        ...     ...  ...              ...       ...       ...         ...         ...         ...     ...     ...  ...       ...
# 227         Wes Iwundu  5152  orl  was     1        20.4     23.1  10.452174   4.086957      12  ...         9.333333        SF  belowAvg   12.137066   23.574019   46.558333    13.1  3500.0   SF  20200208
# 228    Sekou Doumbouya  5866  det  cle     1        12.7     25.4  11.309091   5.545455      15  ...        14.000000        PF  belowAvg   13.700944   22.388779   52.304348     8.6  3700.0   PF  20200208
# 229      Lonnie Walker  5756  sas  mem     0         7.4     26.1  10.117857   5.964286      19  ...        11.666667        SG  belowAvg   12.258862   22.774946   46.519048    11.7  3500.0   SG  20200208
# 230          PJ Dozier  5177  den  gsw     0         0.0     19.8  19.800000  12.000000      12  ...        12.000000        SG  belowAvg   13.264329   23.519867   50.200000     8.0  3600.0   SG  20200208
# 231      Dragan Bender  4913  mil  bkn     0        13.7     14.4  10.325000   3.750000       0  ...         5.000000        PF  belowAvg   15.852732   22.483919   61.636000     0.0  3500.0   PF  20200208
#
# [232 rows x 38 columns]

# %%
fantasy_df.columns
# Out:
# Index(['Name', 'GID', 'Team', 'Opp', 'Home', 'NewGameFDP', 'LastFDP', 'AvgFDP', 'AvgPTS', 'LastPT', 'AvgMIN', 'LastMIN', 'AvgFGM', 'LastFGM', 'AvgFGA', 'LastFGA', 'Avg3PTS', 'Last3PTS', 'AvgREB', 'LastREB', 'AvgAST', 'LastAST', 'AvgSTL', 'AvgTOV', 'LastTOV', 'Date_x', 'Last3GameAvgFDP', 'Last3GameAvgMIN', 'Last3GameAvgPTS', 'position', 'Rank', 'TeamStdFDP', 'TeamAvgFDP', 'TeamMaxFDP', 'FD_Pts', 'FD_Sal', 'Pos', 'Date_y'], dtype='object')

# %%
fantasy_df.corr()['NewGameFDP']
# Out:
# GID               -0.176743
# Home               0.011830
# NewGameFDP         1.000000
# LastFDP            0.572318
# AvgFDP             0.616897
# AvgPTS             0.546202
# LastPT             0.491907
# AvgMIN             0.489936
# LastMIN            0.484224
# AvgFGM             0.156436
# LastFGM            0.073793
# AvgFGA             0.202653
# LastFGA            0.149239
# Avg3PTS            0.222120
# Last3PTS           0.151988
# AvgREB             0.484528
# LastREB            0.374724
# AvgAST             0.392823
# LastAST            0.344566
# AvgSTL             0.125929
# AvgTOV             0.483598
# LastTOV            0.454762
# Last3GameAvgFDP    0.620219
# Last3GameAvgMIN    0.479403
# Last3GameAvgPTS    0.540764
# TeamStdFDP         0.025705
# TeamAvgFDP         0.145168
# TeamMaxFDP         0.052422
# FD_Pts             0.398219
# FD_Sal             0.676721
# Date_y                  NaN
# Name: NewGameFDP, dtype: float64

# %%
to_drop = ['GID', 'Home', 'AvgFGM', 'LastFGM', 'AvgFGA', 'LastFGA', 'Avg3PTS', 'LastREB',  'LastAST', 'AvgSTL', \
           'TeamStdFDP', 'TeamAvgFDP', 'TeamMaxFDP', 'Date_y', 'Last3PTS', 'Team', 'Opp', 'Rank', 'Pos']
fantasy_df.drop(to_drop, axis=1, inplace = True)
fantasy_df
# Out:
#                   Name  NewGameFDP  LastFDP     AvgFDP     AvgPTS  LastPT     AvgMIN    LastMI
# 4    Langston_Galloway        21.1     12.8  12.800000   5.000000       5  20.016667  20.016667   4.000000  0.000000  3.000000        3  2019-10-23        12.800000        20.016667         5.000000       SG     7.4  3900.0
# ..                 ...         ...      ...        ...        ...     ...        ...        ...        ...       ...       ...      ...         ...              ...              ...              ...      ...     ...     ...
# 227         Wes_Iwundu        20.4     23.1  10.452174   4.086957      12  16.496377  28.383333   2.478261  0.869565  0.521739        0  2020-01-07        18.366667        27.244444         9.333333       SF    13.1  3500.0
# 228    Sekou_Doumbouya        12.7     25.4  11.309091   5.545455      15  14.256061  33.366667   2.909091  0.181818  0.454545        1  2020-01-08        27.466667        35.205556        14.000000       PF     8.6  3700.0
# 229      Lonnie_Walker         7.4     26.1  10.117857   5.964286      19  11.814881  19.216667   2.107143  0.607143  0.678571        1  2020-01-09        20.133333        21.444444        11.666667       SG    11.7  3500.0
# 230          PJ_Dozier         0.0     19.8  19.800000  12.000000      12  13.033333  13.033333   4.000000  2.000000  0.000000        0  2020-01-15        19.800000        13.033333        12.000000       SG     8.0  3600.0
# 231      Dragan_Bender        13.7     14.4  10.325000   3.750000       0  12.600000  21.233333   2.250000  1.250000  0.250000        0  2020-01-17        12.600000        16.055556         5.000000       PF     0.0  3500.0
#
# [232 rows x 19 columns]

# %%
# columns = ['Name','FD_Sal']
# temp = temp[columns]

# %%
# fantasy_df = pd.merge(fantasy_df, temp, how='left',on='Name')
# fantasy_df.columns

# %% [markdown]
# # LINEAR MODELING

# %%
# formulate linear programming problem
problem = pulp.LpProblem("Optimal Lineup", pulp.LpMaximize)

# %% [markdown]
# #Defining Variables

# %%
# initialize variables
playerPositions = fantasy_df['position'].tolist()
playerNames = fantasy_df['Name'].tolist()
playerCosts = tuple(fantasy_df['FD_Sal'])
playerPoints = tuple(fantasy_df['NewGameFDP'])
salaryCap = 60000
numOfPlayers = range(len(playerNames))

# %%
# create variable to represent each player
playerInLineup = pulp.LpVariable.dicts("Player", [i for i in numOfPlayers], 0, 1, cat="Binary")

# %% [markdown]
# #Creating the Objective(s)

# %%
# Objective: maximize sum of player points in FanDuel
problem += pulp.lpSum(playerInLineup[i] * playerPoints[i] for i in numOfPlayers)
print(problem)
# Out:
# Optimal_Lineup:
# MAXIMIZE
# 40.6*Player_0 + 23.7*Player_1 + 39.5*Player_10 + 14.9*Player_100 + 3.9*Player_101 + 45.3*Player_102 + 27.2*Player_103 + 3.7*Player_104 + 22.3*Player_105 + 9.7*Player_106 + 26.8*Player_107 + 11.9*Player_108 + 27.8*Player_109 + 3.4*Player_11 + 5.1*Player_110 + 21.4*Player_111 + 13.3*Player_112 + 27.9*Player_113 + 21.5*Player_114 + 12.4*Player_115 + 20.1*Player_116 + 22.9*Player_117 + 25.7*Player_118 + 30.6*Player_119 + 17.4*Player_12 + 19.7*Player_120 + 52.4*Player_121 + 14.2*Player_122 + 12.7*Player_123 + 9.0*Player_124 + 15.4*Player_125 + 15.0*Player_126 + 17.3*Player_127 + 69.9*Player_128 + 33.5*Player_129 + 24.3*Player_13 + 32.2*Player_130 + 35.3*Player_131 + 10.0*Player_132 + 33.1*Player_133 + 21.4*Player_134 + 16
.9*Player_61 + 29.4*Player_62 + 21.2*Player_63 + 31.7*Player_64 + 28.2*Player_65 + 25.0*Player_66 + 6.9*Player_67 + 23.4*Player_68 + 34.5*Player_69 + 14.3*Player_7 + 33.1*Player_70 + 25.0*Player_71 + 23.5*Player_72 + 20.4*Player_73 + 26.6*Player_74 + 19.6*Player_75 + 6.8*Player_76 + 23.2*Player_77 + 46.3*Player_78 + 3.7*Player_79 + 15.2*Player_8 + 17.6*Player_80 + 18.2*Player_81 + 4.0*Player_82 + 11.5*Player_83 + 11.3*Player_84 + 19.4*Player_85 + 47.9*Player_86 + 23.3*Player_87 + 55.0*Player_88 + 3.0*Player_89 + 20.9*Player_9 + 20.4*Player_90 + 21.9*Player_91 + 45.0*Player_92 + 14.2*Player_93 + 10.3*Player_94 + 5.8*Player_95 + 17.9*Player_96 + 24.0*Player_97 + 18.4*Player_98 + 43.3*Player_99 + 0.0
# VARIABLES
# 0 <= Player_0 <= 1 Integer
# 0 <= Player_1 <= 1 Integer
# 0 <= Player_10 <= 1 Integer
# 0 <= Player_100 <= 1 Integer
# 0 <= Player_101 <= 1 Integer
# 0 <= Player_102 <= 1 Integer
# 0 <= Player_103 <= 1 Integer
# 0 <= Player_104 <= 1 Integer
# 0 <= Player_105 <= 1 Integer
# 0 <= Player_106 <= 1 Integer
# 0 <= Player_107 <= 1 Integer
# 0 <= Player_108 <= 1 Integer
# 0 <= Player_109 <= 1 Integer
# 0 <= Player_11 <= 1 Integer
# 0 <= Player_110 <= 1 Integer
# 0 <= Player_111 <= 1 Integer
# 0 <= Player_112 <= 1 Integer
# 0 <= Player_113 <= 1 Integer
# 0 <= Player_114 <= 1 Integer
# 0 <= Player_115 <= 1 Integer
# 0 <= Player_116 <= 1 Integer
# 0 <= Player_117 <= 1 Integer
# 0 <= Player_118 <= 1 Integer
# 0 <= Player_119 <= 1 Integer
# 0 <= Player_12 <= 1 Integer
# 0 <= Player_120 <= 1 Integer
# 0 <= Player_121 <= 1 Integer
# 0 <= Player_122 <= 1 Integer
# 0 <= Player_123 <= 1 Integer
# 0 <= Player_124 <= 1 Integer
# 0 <= Player_125 <= 1 Integer
# 0 <= Player_126 <= 1 Integer
# 0 <= Player_127 <= 1 Integer
# 0 <= Player_128 <= 1 Integer
# 0 <= Player_129 <= 1 Integer
# 0 <= Player_13 <= 1 Integer
# 0 <= Player_130 <= 1 Integer
# 0 <= Player_131 <= 1 Integer
# 0 <= Player_132 <= 1 Integer
# 0 <= Player_133 <= 1 Integer
# 0 <= Player_134 <= 1 Integer
# 0 <= Player_135 <= 1 Integer
# 0 <= Player_136 <= 1 Integer
# 0 <= Player_137 <= 1 Integer
# 0 <= Player_138 <= 1 Integer
# 0 <= Player_139 <= 1 Integer
# 0 <= Player_14 <= 1 Integer
# 0 <= Player_140 <= 1 Integer
# 0 <= Player_141 <= 1 Integer
# 0 <= Player_142 <= 1 Integer
# 0 <= Player_143 <= 1 Integer
# 0 <= Player_144 <= 1 Integer
# 0 <= Player_145 <= 1 Integer
# 0 <= Player_146 <= 1 Integer
# 0 <= Player_147 <= 1 Integer
# 0 <= Player_148 <= 1 Integer
# 0 <= Player_149 <= 1 Integer
# 0 <= Player_15 <= 1 Integer
# 0 <= Player_150 <= 1 Integer
# 0 <= Player_151 <= 1 Integer
# 0 <= Player_152 <= 1 Integer
# 0 <= Player_153 <= 1 Integer
# 0 <= Player_154 <= 1 Integer
# 0 <= Player_155 <= 1 Integer
# 0 <= Player_156 <= 1 Integer
# 0 <= Player_157 <= 1 Integer
# 0 <= Player_158 <= 1 Integer
# 0 <= Player_159 <= 1 Integer
# 0 <= Player_16 <= 1 Integer
# 0 <= Player_160 <= 1 Integer
# 0 <= Player_161 <= 1 Integer
# 0 <= Player_162 <= 1 Integer
# 0 <= Player_163 <= 1 Integer
# 0 <= Player_165 <= 1 Integer
# 0 <= Player_166 <= 1 Integer
# 0 <= Player_167 <= 1 Integer
# 0 <= Player_168 <= 1 Integer
# 0 <= Player_169 <= 1 Integer
# 0 <= Player_17 <= 1 Integer
# 0 <= Player_170 <= 1 Integer
# 0 <= Player_171 <= 1 Integer
# 0 <= Player_172 <= 1 Integer
# 0 <= Player_173 <= 1 Integer
# 0 <= Player_174 <= 1 Integer
# 0 <= Player_175 <= 1 Integer
# 0 <= Player_176 <= 1 Integer
# 0 <= Player_177 <= 1 Integer
# 0 <= Player_178 <= 1 Integer
# 0 <= Player_179 <= 1 Integer
# 0 <= Player_18 <= 1 Integer
# 0 <= Player_180 <= 1 Integer
# 0 <= Player_181 <= 1 Integer
# 0 <= Player_182 <= 1 Integer
# 0 <= Player_183 <= 1 Integer
# 0 <= Player_184 <= 1 Integer
# 0 <= Player_185 <= 1 Integer
# 0 <= Player_186 <= 1 Integer
# 0 <= Player_187 <= 1 Integer
# 0 <= Player_188 <= 1 Integer
# 0 <= Player_189 <= 1 Integer
# 0 <= Player_19 <= 1 Integer
# 0 <= Player_190 <= 1 Integer
# 0 <= Player_191 <= 1 Integer
# 0 <= Player_192 <= 1 Integer
# 0 <= Player_193 <= 1 Integer
# 0 <= Player_194 <= 1 Integer
# 0 <= Player_195 <= 1 Integer
# 0 <= Player_196 <= 1 Integer
# 0 <= Player_197 <= 1 Integer
# 0 <= Player_198 <= 1 Integer
# 0 <= Player_199 <= 1 Integer
# 0 <= Player_2 <= 1 Integer
# 0 <= Player_20 <= 1 Integer
# 0 <= Player_200 <= 1 Integer
# 0 <= Player_201 <= 1 Integer
# 0 <= Player_202 <= 1 Integer
# 0 <= Player_203 <= 1 Integer
# 0 <= Player_204 <= 1 Integer
# 0 <= Player_205 <= 1 Integer
# 0 <= Player_206 <= 1 Integer
# 0 <= Player_207 <= 1 Integer
# 0 <= Player_208 <= 1 Integer
# 0 <= Player_209 <= 1 Integer
# 0 <= Player_21 <= 1 Integer
# 0 <= Player_210 <= 1 Integer
# 0 <= Player_211 <= 1 Integer
# 0 <= Player_212 <= 1 Integer
# 0 <= Player_213 <= 1 Integer
# 0 <= Player_214 <= 1 Integer
# 0 <= Player_215 <= 1 Integer
# 0 <= Player_216 <= 1 Integer
# 0 <= Player_217 <= 1 Integer
# 0 <= Player_218 <= 1 Integer
# 0 <= Player_219 <= 1 Integer
# 0 <= Player_22 <= 1 Integer
# 0 <= Player_220 <= 1 Integer
# 0 <= Player_221 <= 1 Integer
# 0 <= Player_222 <= 1 Integer
# 0 <= Player_223 <= 1 Integer
# 0 <= Player_224 <= 1 Integer
# 0 <= Player_225 <= 1 Integer
# 0 <= Player_226 <= 1 Integer
# 0 <= Player_227 <= 1 Integer
# 0 <= Player_228 <= 1 Integer
# 0 <= Player_229 <= 1 Integer
# 0 <= Player_23 <= 1 Integer
# 0 <= Player_231 <= 1 Integer
# 0 <= Player_24 <= 1 Integer
# 0 <= Player_25 <= 1 Integer
# 0 <= Player_26 <= 1 Integer
# 0 <= Player_27 <= 1 Integer
# 0 <= Player_28 <= 1 Integer
# 0 <= Player_29 <= 1 Integer
# 0 <= Player_3 <= 1 Integer
# 0 <= Player_30 <= 1 Integer
# 0 <= Player_31 <= 1 Integer
# 0 <= Player_32 <= 1 Integer
# 0 <= Player_33 <= 1 Integer
# 0 <= Player_34 <= 1 Integer
# 0 <= Player_35 <= 1 Integer
# 0 <= Player_36 <= 1 Integer
# 0 <= Player_37 <= 1 Integer
# 0 <= Player_38 <= 1 Integer
# 0 <= Player_39 <= 1 Integer
# 0 <= Player_4 <= 1 Integer
# 0 <= Player_40 <= 1 Integer
# 0 <= Player_41 <= 1 Integer
# 0 <= Player_42 <= 1 Integer
# 0 <= Player_43 <= 1 Integer
# 0 <= Player_44 <= 1 Integer
# 0 <= Player_45 <= 1 Integer
# 0 <= Player_46 <= 1 Integer
# 0 <= Player_47 <= 1 Integer
# 0 <= Player_48 <= 1 Integer
# 0 <= Player_49 <= 1 Integer
# 0 <= Player_5 <= 1 Integer
# 0 <= Player_50 <= 1 Integer
# 0 <= Player_51 <= 1 Integer
# 0 <= Player_52 <= 1 Integer
# 0 <= Player_53 <= 1 Integer
# 0 <= Player_54 <= 1 Integer
# 0 <= Player_55 <= 1 Integer
# 0 <= Player_56 <= 1 Integer
# 0 <= Player_57 <= 1 Integer
# 0 <= Player_58 <= 1 Integer
# 0 <= Player_59 <= 1 Integer
# 0 <= Player_6 <= 1 Integer
# 0 <= Player_60 <= 1 Integer
# 0 <= Player_61 <= 1 Integer
# 0 <= Player_62 <= 1 Integer
# 0 <= Player_63 <= 1 Integer
# 0 <= Player_64 <= 1 Integer
# 0 <= Player_65 <= 1 Integer
# 0 <= Player_66 <= 1 Integer
# 0 <= Player_67 <= 1 Integer
# 0 <= Player_68 <= 1 Integer
# 0 <= Player_69 <= 1 Integer
# 0 <= Player_7 <= 1 Integer
# 0 <= Player_70 <= 1 Integer
# 0 <= Player_71 <= 1 Integer
# 0 <= Player_72 <= 1 Integer
# 0 <= Player_73 <= 1 Integer
# 0 <= Player_74 <= 1 Integer
# 0 <= Player_75 <= 1 Integer
# 0 <= Player_76 <= 1 Integer
# 0 <= Player_77 <= 1 Integer
# 0 <= Player_78 <= 1 Integer
# 0 <= Player_79 <= 1 Integer
# 0 <= Player_8 <= 1 Integer
# 0 <= Player_80 <= 1 Integer
# 0 <= Player_81 <= 1 Integer
# 0 <= Player_82 <= 1 Integer
# 0 <= Player_83 <= 1 Integer
# 0 <= Player_84 <= 1 Integer
# 0 <= Player_85 <= 1 Integer
# 0 <= Player_86 <= 1 Integer
# 0 <= Player_87 <= 1 Integer
# 0 <= Player_88 <= 1 Integer
# 0 <= Player_89 <= 1 Integer
# 0 <= Player_9 <= 1 Integer
# 0 <= Player_90 <= 1 Integer
# 0 <= Player_91 <= 1 Integer
# 0 <= Player_92 <= 1 Integer
# 0 <= Player_93 <= 1 Integer
# 0 <= Player_94 <= 1 Integer
# 0 <= Player_95 <= 1 Integer
# 0 <= Player_96 <= 1 Integer
# 0 <= Player_97 <= 1 Integer
# 0 <= Player_98 <= 1 Integer
# 0 <= Player_99 <= 1 Integer

# %% [markdown]
# # Defining the Contraints

# %%
# constraint n1: each player can only be chosen at most once
for i in numOfPlayers:
    problem += pulp.lpSum(playerInLineup[i]) <= 1

# %%
# constraint n2: sum of player costs cannot be more than or equal to FanDuel Salary cap ($ 60,000)
problem += sum(playerInLineup[i] * playerCosts[i] for i in numOfPlayers) <= salaryCap

# %%
# constraint n3: teams can have up to 9 players
problem += pulp.lpSum(problem.variables()) == 9

# %% [markdown]
# #Player Positions

# %%
# constraint n4: number of PG = 2
pointguards = tuple(fantasy_df['position'] == 'PG')
problem += pulp.lpSum(playerInLineup[i] * pointguards[i] for i in numOfPlayers) >=1
problem += pulp.lpSum(playerInLineup[i] * pointguards[i] for i in numOfPlayers) <= 2

# %%
# constraint n5: number of SG = 2
shootinguard = tuple(fantasy_df['position'] == 'SG')
problem += pulp.lpSum(playerInLineup[i] * shootinguard[i] for i in numOfPlayers) >=2
problem += pulp.lpSum(playerInLineup[i] * shootinguard[i] for i in numOfPlayers) <= 2

# %%
# constraint n6: number of SF = 2
smallforward = tuple(fantasy_df['position'] == 'SF')
problem += pulp.lpSum(playerInLineup[i] * smallforward[i] for i in numOfPlayers) >=2
problem += pulp.lpSum(playerInLineup[i] * smallforward[i] for i in numOfPlayers) <= 2

# %%
# constraint n7: number of PF = 2
powerforward = tuple(fantasy_df['position'] == 'PF')
problem += pulp.lpSum(playerInLineup[i] * powerforward[i] for i in numOfPlayers) >=2
problem += pulp.lpSum(playerInLineup[i] * powerforward[i] for i in numOfPlayers) <= 2

# %%
# constraint n8: number of C = 1
center = tuple(fantasy_df['position'] == 'C')
problem += pulp.lpSum(playerInLineup[i] * center[i] for i in numOfPlayers) >=1
problem += pulp.lpSum(playerInLineup[i] * center[i] for i in numOfPlayers) <= 1

# %% [markdown]
# # Solving the Problem

# %%
# calculating predicted lineup
cost = 0
points = 0

predicted = set()
if problem.solve() == 1:
    for pos in range(len(numOfPlayers)):
        if playerInLineup[pos].value() == 1:
            name = playerNames[pos]
            predicted.add(name)
            cost += playerCosts[pos]
            points += playerPoints[pos]
            print (playerNames[pos], playerPositions[pos], playerCosts[pos],playerPoints[pos])
    print ('-------------------')
    print (f"The total cost is =: {cost}")
    print (f"The predicted FanDuel points: {points}")
else:
    print ('Error finding solution')
# Out:
# Karl-Anthony_Towns C 10000.0 83.0
# RJ_Barrett SG 4900.0 37.1
# Delon_Wright SG 4600.0 47.9
# LaMarcus_Aldridge PF 6800.0 45.3
# Malcolm_Brogdon PG 6700.0 52.4
# Giannis_Antetokounmpo SF 11500.0 69.9
# Stephen_Curry PG 3500.0 38.1
# Omari_Spellman PF 3500.0 35.6
# Paul_George SF 8400.0 52.3
# -------------------
# The total cost is =: 59900.0
# The predicted FanDuel points: 461.6000000000001
