# %%
# %matplotlib inline
import glob
import matplotlib.pyplot as plt
import pandas as pd
import pulp
import csv


pandas.set_option('display.width', 1000)

# %%
# create dataframe of past salaries and past performance
fantasy_df = pd.read_csv("../Data/predicted2.csv")

# Print the first five rows of data to the screen
fantasy_df.head()
# Out:
#         Player_Name  FD_pos position  FD_Sal   PFDP  Last_FDP         Rank         pt        rb        as    st        bl        to   trey       FGM        FGA       FTM       FTA
# 0          Alex_Len       5        C    4400   7.64      16.8     belowAvg   8.725000  5.775000  1.050000  0.50  0.825000  1.000000  0.350  3.300000   6.125000  1.275000  2.025000
# 1   Al-Farouq_Aminu       4       PF    3800   9.72      12.9     belowAvg   4.333333  4.888889  1.166667  1.00  0.444444  0.944444  0.500  1.388889   4.777778  1.055556  1.611111
# 2  Alfonzo_McKinnie       3       SF    3700   4.06       7.4  benchPlayer   4.125000  2.843750  0.375000  0.50  0.187500  0.593750  0.375  1.625000   3.906250  0.500000  0.718750
# 3    Andrew_Wiggins       2       SG    7700  21.56      21.5      average  22.675000  5.150000  3.675000  0.65  0.850000  2.425000  2.200  4.175000  10.375000  3.525000  4.875000
# 4   Anfernee_Simons       1       PG    3500  12.05      16.5     belowAvg   8.920000  2.480000  1.500000  0.34  0.180000  1.000000  1.080  3.360000   8.320000  1.120000  1.400000

# %%
pastsalaries['DK Pts']= round(pastsalaries['DK Pts'])
pastsalaries['DK Pts']= pastsalaries['DK Pts'].astype(int)
pastsalaries
# Out:
#          Date   GID Pos                Name  Starter  DK Pts DK Salary Team H/A Oppt Team Score  Oppt Score Minutes                                     Stat line
# 0    20151116  4382  PG      Knight_Brandon      1.0      78      7000  pho   H  lal        120       101.0   40.78    30pt 10rb 15as 4st 2to 3trey 11-23fg 5-7ft
# 1    20151116  4079  PG   Westbrook_Russell      1.0      72     12200  okc   A  mem        114       122.0   38.53    40pt 4rb 14as 3st 8to 5trey 13-19fg 9-13ft
# 2    20151116  4523  PG      Lillard_Damian      1.0      48      8700  por   A  sas         80        93.0   41.97  27pt 7rb 6as 1st 1bl 3to 1trey 10-21fg 6-6ft
# 3    20151116  3979  PG         Conley_Mike      1.0      46      6000  mem   H  okc        122       114.0   31.38           22pt 4rb 9as 2st 4trey 8-13fg 2-3ft
# 4    20151116  4073  PG        Rose_Derrick      1.0      42      5900  chi   H  ind         96        95.0   33.22       23pt 2rb 6as 2st 1bl 2trey 9-18fg 3-4ft
# ..        ...   ...  ..                 ...      ...     ...       ...  ...  ..  ...        ...         ...     ...                                           ...
# 141  20160313  4535   C        Sacre_Robert      NaN       0      3000  lal   H  nyk         87        90.0     NaN                                           0pt
# 142  20160313  4304   C        Pleiss_Tibor      NaN       0      3000  uta   A  sac        108        99.0     NaN                                           0pt
# 143  20160313  4024   C      Splitter_Tiago      NaN       0      3000  atl   H  ind        104        75.0     NaN                                           0pt
# 144  20160313  4687   C  Whittington_Shayne      NaN       0      3000  ind   A  atl         75       104.0     NaN                                           0pt
# 145  20160313  4867   C      Tavares_Walter      NaN       0      3000  atl   H  ind        104        75.0     NaN                                           0pt
#
# [24627 rows x 14 columns]

# %%
# choose an arbitrary date
date = 20151116

# %%
# isolate data for specific date
specificDate = pastsalaries[pastsalaries['Date'] == date]

# exclude players with missing salaries
specificDate = specificDate[specificDate['DK Salary'] != 'nan']

# %%
# initialize variables
playerPositions = specificDate['Pos'].tolist()
teams = specificDate['Team'].tolist()
playerNames = specificDate['Name'].tolist()
playerTeams = tuple(specificDate['Team'].unique())
playerCosts = tuple(specificDate['DK Salary'])
playerPoints = tuple(specificDate['DK Pts'])
salaryCap = 60000
numOfPlayers = range(len(playerCosts))

# %%
# formulate linear programming problem
problem = pulp.LpProblem("Optimal Lineup", pulp.LpMaximize)

# %%
# create variable to represent each player
playerInLineup = pulp.LpVariable.dicts("Players", [i for i in numOfPlayers], 0, 1, cat="Binary")

# %%
# create objective: maximize sum of player points
problem += pulp.lpSum(playerInLineup[i] * playerPoints[i] for i in numOfPlayers)

# %%
# constraint: each player can only be chosen at most once
for i in numOfPlayers:
    problem += pulp.lpSum(playerInLineup[i]) <= 1

# %%
# constraints: sum of player costs must be less than or equal to the salary cap
problem += sum(playerInLineup[i] * playerCosts[i] for i in numOfPlayers) <= salaryCap

# %%
# constraint: teams must have 8 players
problem += pulp.lpSum(problem.variables()) == 9
problem
# Out:
# Optimal_Lineup:
# MAXIMIZE
# 78*Players_0 + 72*Players_1 + 32*Players_10 + 16*Players_100 + 15*Players_101 + 15*Players_102 + 15*Players_103 + 14*Players_104 + 13*Players_105 + 12*Players_106 + 12*Players_107 + 11*Players_108 + 10*Players_109 + 30*Players_11 + 10*Players_110 + 10*Players_111 + 7*Players_112 + 7*Players_113 + 7*Players_114 + 7*Players_115 + 6*Players_116 + 6*Players_117 + 6*Players_118 + 5*Players_119 + 29*Players_12 + 5*Players_120 + 4*Players_121 + 4*Players_122 + 2*Players_123 + 2*Players_124 + 28*Players_13 + 27*Players_14 + 26*Players_15 + 40*Players_151 + 34*Players_152 + 29*Players_153 + 29*Players_154 + 28*Players_155 + 26*Players_156 + 26*Players_157 + 25*Players_158 + 24*Players_159 + 26*Players_16 + 24*Players_160 + 22*Players_161 + 22*Players_162 + 20*Players_163 + 17*Players_164 + 16*Players_165 + 14*Players_166 + 12*Players_167 + 8*Players_168 + 26*Players_17 + 25*Players_18 + 25*Players_19 + 48*Players_2 + 24*Players_20 + 23*Players_21 + 22*Players_22 + 22*Players_23 + 21*Players_24 + 19*Players_25 + 18*Players_26 + 17*Players_27 + 17*Players_28 + 15*Players_29 + 46*Players_3 + 15*Players_30 + 14*Players_31 + 14*Players_32 + 14*Players_33 + 13*Players_34 + 12*Players_35 + 12*Players_36 + 12*Players_37 + 10*Players_38 + 10*Players_39 + 42*Players_4 + 9*Players_40 + 9*Players_41 + 8*Players_42 + 8*Players_43 + 7*Players_44 + 6*Players_45 + 6*Players_46 + 6*Players_47 + 5*Players_48 + 4*Players_49 + 41*Players_5 + 4*Players_50 + 3*Players_51 + 2*Players_52 + 36*Players_6 + 36*Players_7 + 44*Players_72 + 42*Players_73 + 38*Players_74 + 38*Players_75 + 35*Players_76 + 34*Players_77 + 34*Players_78 + 32*Players_79 + 35*Players_8 + 32*Players_80 + 32*Players_81 + 30*Players_82 + 28*Players_83 + 28*Players_84 + 27*Players_85 + 26*Players_86 + 26*Players_87 + 24*Players_88 + 24*Players_89 + 32*Players_9 + 24*Players_90 + 24*Players_91 + 23*Players_92 + 23*Players_93 + 21*Players_94 + 20*Players_95 + 20*Players_96 + 17*Players_97 + 17*Players_98 + 16*Players_99 + 0
# SUBJECT TO
# _C1: Players_0 <= 1
#
# _C2: Players_1 <= 1
#
# _C3: Players_2 <= 1
#
# _C4: Players_3 <= 1
#
# _C5: Players_4 <= 1
#
# _C6: Players_5 <= 1
#
# _C7: Players_6 <= 1
#
# _C8: Players_7 <= 1
#
# _C9: Players_8 <= 1
#
# _C10: Players_9 <= 1
#
# _C11: Players_10 <= 1
#
# _C12: Players_11 <= 1
#
# _C13: Players_12 <= 1
#
# _C14: Players_13 <= 1
#
# _C15: Players_14 <= 1
#
# _C16: Players_15 <= 1
#
# _C17: Players_16 <= 1
#
# _C18: Players_17 <= 1
#
# _C19: Players_18 <= 1
#
# _C20: Players_19 <= 1
#
# _C21: Players_20 <= 1
#
# _C22: Players_21 <= 1
#
# _C23: Players_22 <= 1
#
# _C24: Players_23 <= 1
#
# _C25: Players_24 <= 1
#
# _C26: Players_25 <= 1
#
# _C27: Players_26 <= 1
#
# _C28: Players_27 <= 1
#
# _C29: Players_28 <= 1
#
# _C30: Players_29 <= 1
#
# _C31: Players_30 <= 1
#
# _C32: Players_31 <= 1
#
# _C33: Players_32 <= 1
#
# _C34: Players_33 <= 1
#
# _C35: Players_34 <= 1
#
# _C36: Players_35 <= 1
#
# _C37: Players_36 <= 1
#
# _C38: Players_37 <= 1
#
# _C39: Players_38 <= 1
#
# _C40: Players_39 <= 1
#
# _C41: Players_40 <= 1
#
# _C42: Players_41 <= 1
#
# _C43: Players_42 <= 1
#
# _C44: Players_43 <= 1
#
# _C45: Players_44 <= 1
#
# _C46: Players_45 <= 1
#
# _C47: Players_46 <= 1
#
# _C48: Players_47 <= 1
#
# _C49: Players_48 <= 1
#
# _C50: Players_49 <= 1
#
# _C51: Players_50 <= 1
#
# _C52: Players_51 <= 1
#
# _C53: Players_52 <= 1
#
# _C54: Players_53 <= 1
#
# _C55: Players_54 <= 1
#
# _C56: Players_55 <= 1
#
# _C57: Players_56 <= 1
#
# _C58: Players_57 <= 1
#
# _C59: Players_58 <= 1
#
# _C60: Players_59 <= 1
#
# _C61: Players_60 <= 1
#
# _C62: Players_61 <= 1
#
# _C63: Players_62 <= 1
#
# _C64: Players_63 <= 1
#
# _C65: Players_64 <= 1
#
# _C66: Players_65 <= 1
#
# _C67: Players_66 <= 1
#
# _C68: Players_67 <= 1
#
# _C69: Players_68 <= 1
#
# _C70: Players_69 <= 1
#
# _C71: Players_70 <= 1
#
# _C72: Players_71 <= 1
#
# _C73: Players_72 <= 1
#
# _C74: Players_73 <= 1
#
# _C75: Players_74 <= 1
#
# _C76: Players_75 <= 1
#
# _C77: Players_76 <= 1
#
# _C78: Players_77 <= 1
#
# _C79: Players_78 <= 1
#
# _C80: Players_79 <= 1
#
# _C81: Players_80 <= 1
#
# _C82: Players_81 <= 1
#
# _C83: Players_82 <= 1
#
# _C84: Players_83 <= 1
#
# _C85: Players_84 <= 1
#
# _C86: Players_85 <= 1
#
# _C87: Players_86 <= 1
#
# _C88: Players_87 <= 1
#
# _C89: Players_88 <= 1
#
# _C90: Players_89 <= 1
#
# _C91: Players_90 <= 1
#
# _C92: Players_91 <= 1
#
# _C93: Players_92 <= 1
#
# _C94: Players_93 <= 1
#
# _C95: Players_94 <= 1
#
# _C96: Players_95 <= 1
#
# _C97: Players_96 <= 1
#
# _C98: Players_97 <= 1
#
# _C99: Players_98 <= 1
#
# _C100: Players_99 <= 1
#
# _C101: Players_100 <= 1
#
# _C102: Players_101 <= 1
#
# _C103: Players_102 <= 1
#
# _C104: Players_103 <= 1
#
# _C105: Players_104 <= 1
#
# _C106: Players_105 <= 1
#
# _C107: Players_106 <= 1
#
# _C108: Players_107 <= 1
#
# _C109: Players_108 <= 1
#
# _C110: Players_109 <= 1
#
# _C111: Players_110 <= 1
#
# _C112: Players_111 <= 1
#
# _C113: Players_112 <= 1
#
# _C114: Players_113 <= 1
#
# _C115: Players_114 <= 1
#
# _C116: Players_115 <= 1
#
# _C117: Players_116 <= 1
#
# _C118: Players_117 <= 1
#
# _C119: Players_118 <= 1
#
# _C120: Players_119 <= 1
#
# _C121: Players_120 <= 1
#
# _C122: Players_121 <= 1
#
# _C123: Players_122 <= 1
#
# _C124: Players_123 <= 1
#
# _C125: Players_124 <= 1
#
# _C126: Players_125 <= 1
#
# _C127: Players_126 <= 1
#
# _C128: Players_127 <= 1
#
# _C129: Players_128 <= 1
#
# _C130: Players_129 <= 1
#
# _C131: Players_130 <= 1
#
# _C132: Players_131 <= 1
#
# _C133: Players_132 <= 1
#
# _C134: Players_133 <= 1
#
# _C135: Players_134 <= 1
#
# _C136: Players_135 <= 1
#
# _C137: Players_136 <= 1
#
# _C138: Players_137 <= 1
#
# _C139: Players_138 <= 1
#
# _C140: Players_139 <= 1
#
# _C141: Players_140 <= 1
#
# _C142: Players_141 <= 1
#
# _C143: Players_142 <= 1
#
# _C144: Players_143 <= 1
#
# _C145: Players_144 <= 1
#
# _C146: Players_145 <= 1
#
# _C147: Players_146 <= 1
#
# _C148: Players_147 <= 1
#
# _C149: Players_148 <= 1
#
# _C150: Players_149 <= 1
#
# _C151: Players_150 <= 1
#
# _C152: Players_151 <= 1
#
# _C153: Players_152 <= 1
#
# _C154: Players_153 <= 1
#
# _C155: Players_154 <= 1
#
# _C156: Players_155 <= 1
#
# _C157: Players_156 <= 1
#
# _C158: Players_157 <= 1
#
# _C159: Players_158 <= 1
#
# _C160: Players_159 <= 1
#
# _C161: Players_160 <= 1
#
# _C162: Players_161 <= 1
#
# _C163: Players_162 <= 1
#
# _C164: Players_163 <= 1
#
# _C165: Players_164 <= 1
#
# _C166: Players_165 <= 1
#
# _C167: Players_166 <= 1
#
# _C168: Players_167 <= 1
#
# _C169: Players_168 <= 1
#
# _C170: Players_169 <= 1
#
# _C171: Players_170 <= 1
#
# _C172: Players_171 <= 1
#
# _C173: Players_172 <= 1
#
# _C174: Players_173 <= 1
#
# _C175: Players_174 <= 1
#
# _C176: Players_175 <= 1
#
# _C177: Players_176 <= 1
#
# _C178: Players_177 <= 1
#
# _C179: Players_178 <= 1
#
# _C180: 7000 Players_0 + 12200 Players_1 + 4500 Players_10 + 4700 Players_100
#  + 3000 Players_101 + 3100 Players_102 + 3600 Players_103 + 6100 Players_104
#  + 6000 Players_105 + 3200 Players_106 + 3000 Players_107 + 3000 Players_108
#  + 3000 Players_109 + 4300 Players_11 + 3400 Players_110 + 3400 Players_111
#  + 3100 Players_112 + 3600 Players_113 + 3000 Players_114 + 3000 Players_115
#  + 3000 Players_116 + 3200 Players_117 + 3000 Players_118 + 3000 Players_119
#  + 8400 Players_12 + 3000 Players_120 + 4400 Players_121 + 3800 Players_122
#  + 3000 Players_123 + 3000 Players_124 + 3000 Players_125 + 3000 Players_126
#  + 3000 Players_127 + 3000 Players_128 + 3200 Players_129 + 4600 Players_13
#  + 3000 Players_130 + 5800 Players_131 + 3000 Players_132 + 3000 Players_133
#  + 3000 Players_134 + 3000 Players_135 + 3000 Players_136 + 3000 Players_137
#  + 3000 Players_138 + 3000 Players_139 + 4600 Players_14 + 4600 Players_140
#  + 9900 Players_141 + 3000 Players_142 + 3000 Players_143 + 3000 Players_144
#  + 3000 Players_145 + 3000 Players_146 + 3000 Players_147 + 3000 Players_148
#  + 3000 Players_149 + 4300 Players_15 + 3000 Players_150 + 7200 Players_151
#  + 7000 Players_152 + 6200 Players_153 + 3900 Players_154 + 4900 Players_155
#  + 5400 Players_156 + 7400 Players_157 + 3800 Players_158 + 4700 Players_159
#  + 4100 Players_16 + 3000 Players_160 + 5500 Players_161 + 3900 Players_162
#  + 3000 Players_163 + 5300 Players_164 + 3000 Players_165 + 5700 Players_166
#  + 3000 Players_167 + 3100 Players_168 + 3000 Players_169 + 5600 Players_17
#  + 3000 Players_170 + 3000 Players_171 + 3200 Players_172 + 3000 Players_173
#  + 3000 Players_174 + 3000 Players_175 + 3000 Players_176 + 3000 Players_177
#  + 4200 Players_178 + 5200 Players_18 + 4500 Players_19 + 8700 Players_2
#  + 3000 Players_20 + 6700 Players_21 + 3500 Players_22 + 10300 Players_23
#  + 3600 Players_24 + 4200 Players_25 + 4600 Players_26 + 5600 Players_27
#  + 3300 Players_28 + 5000 Players_29 + 6000 Players_3 + 3000 Players_30
#  + 4600 Players_31 + 3500 Players_32 + 3300 Players_33 + 3000 Players_34
#  + 5700 Players_35 + 3600 Players_36 + 3800 Players_37 + 3100 Players_38
#  + 3200 Players_39 + 5900 Players_4 + 3000 Players_40 + 3500 Players_41
#  + 3000 Players_42 + 4000 Players_43 + 3200 Players_44 + 3000 Players_45
#  + 3000 Players_46 + 3600 Players_47 + 3000 Players_48 + 4500 Players_49
#  + 7100 Players_5 + 3000 Players_50 + 3000 Players_51 + 3000 Players_52
#  + 3000 Players_53 + 3000 Players_54 + 3000 Players_55 + 3400 Players_56
#  + 3000 Players_57 + 3000 Players_58 + 3800 Players_59 + 3200 Players_6
#  + 3000 Players_60 + 3000 Players_61 + 6000 Players_62 + 3000 Players_63
#  + 3300 Players_64 + 3000 Players_65 + 3000 Players_66 + 6100 Players_67
#  + 3100 Players_68 + 3000 Players_69 + 5800 Players_7 + 4900 Players_70
#  + 3000 Players_71 + 8200 Players_72 + 9200 Players_73 + 5500 Players_74
#  + 3600 Players_75 + 6900 Players_76 + 3500 Players_77 + 6800 Players_78
#  + 6000 Players_79 + 5400 Players_8 + 6500 Players_80 + 4000 Players_81
#  + 3200 Players_82 + 6300 Players_83 + 3800 Players_84 + 7400 Players_85
#  + 4300 Players_86 + 4600 Players_87 + 5500 Players_88 + 3400 Players_89
#  + 7800 Players_9 + 6000 Players_90 + 5800 Players_91 + 3500 Players_92
#  + 3000 Players_93 + 4800 Players_94 + 4800 Players_95 + 3200 Players_96
#  + 4600 Players_97 + 7100 Players_98 + 3700 Players_99 <= 60000
#
# _C181: Players_0 + Players_1 + Players_10 + Players_100 + Players_101
#  + Players_102 + Players_103 + Players_104 + Players_105 + Players_106
#  + Players_107 + Players_108 + Players_109 + Players_11 + Players_110
#  + Players_111 + Players_112 + Players_113 + Players_114 + Players_115
#  + Players_116 + Players_117 + Players_118 + Players_119 + Players_12
#  + Players_120 + Players_121 + Players_122 + Players_123 + Players_124
#  + Players_125 + Players_126 + Players_127 + Players_128 + Players_129
#  + Players_13 + Players_130 + Players_131 + Players_132 + Players_133
#  + Players_134 + Players_135 + Players_136 + Players_137 + Players_138
#  + Players_139 + Players_14 + Players_140 + Players_141 + Players_142
#  + Players_143 + Players_144 + Players_145 + Players_146 + Players_147
#  + Players_148 + Players_149 + Players_15 + Players_150 + Players_151
#  + Players_152 + Players_153 + Players_154 + Players_155 + Players_156
#  + Players_157 + Players_158 + Players_159 + Players_16 + Players_160
#  + Players_161 + Players_162 + Players_163 + Players_164 + Players_165
#  + Players_166 + Players_167 + Players_168 + Players_169 + Players_17
#  + Players_170 + Players_171 + Players_172 + Players_173 + Players_174
#  + Players_175 + Players_176 + Players_177 + Players_178 + Players_18
#  + Players_19 + Players_2 + Players_20 + Players_21 + Players_22 + Players_23
#  + Players_24 + Players_25 + Players_26 + Players_27 + Players_28 + Players_29
#  + Players_3 + Players_30 + Players_31 + Players_32 + Players_33 + Players_34
#  + Players_35 + Players_36 + Players_37 + Players_38 + Players_39 + Players_4
#  + Players_40 + Players_41 + Players_42 + Players_43 + Players_44 + Players_45
#  + Players_46 + Players_47 + Players_48 + Players_49 + Players_5 + Players_50
#  + Players_51 + Players_52 + Players_53 + Players_54 + Players_55 + Players_56
#  + Players_57 + Players_58 + Players_59 + Players_6 + Players_60 + Players_61
#  + Players_62 + Players_63 + Players_64 + Players_65 + Players_66 + Players_67
#  + Players_68 + Players_69 + Players_7 + Players_70 + Players_71 + Players_72
#  + Players_73 + Players_74 + Players_75 + Players_76 + Players_77 + Players_78
#  + Players_79 + Players_8 + Players_80 + Players_81 + Players_82 + Players_83
#  + Players_84 + Players_85 + Players_86 + Players_87 + Players_88 + Players_89
#  + Players_9 + Players_90 + Players_91 + Players_92 + Players_93 + Players_94
#  + Players_95 + Players_96 + Players_97 + Players_98 + Players_99 = 9
#
# VARIABLES
# 0 <= Players_0 <= 1 Integer
# 0 <= Players_1 <= 1 Integer
# 0 <= Players_10 <= 1 Integer
# 0 <= Players_100 <= 1 Integer
# 0 <= Players_101 <= 1 Integer
# 0 <= Players_102 <= 1 Integer
# 0 <= Players_103 <= 1 Integer
# 0 <= Players_104 <= 1 Integer
# 0 <= Players_105 <= 1 Integer
# 0 <= Players_106 <= 1 Integer
# 0 <= Players_107 <= 1 Integer
# 0 <= Players_108 <= 1 Integer
# 0 <= Players_109 <= 1 Integer
# 0 <= Players_11 <= 1 Integer
# 0 <= Players_110 <= 1 Integer
# 0 <= Players_111 <= 1 Integer
# 0 <= Players_112 <= 1 Integer
# 0 <= Players_113 <= 1 Integer
# 0 <= Players_114 <= 1 Integer
# 0 <= Players_115 <= 1 Integer
# 0 <= Players_116 <= 1 Integer
# 0 <= Players_117 <= 1 Integer
# 0 <= Players_118 <= 1 Integer
# 0 <= Players_119 <= 1 Integer
# 0 <= Players_12 <= 1 Integer
# 0 <= Players_120 <= 1 Integer
# 0 <= Players_121 <= 1 Integer
# 0 <= Players_122 <= 1 Integer
# 0 <= Players_123 <= 1 Integer
# 0 <= Players_124 <= 1 Integer
# 0 <= Players_125 <= 1 Integer
# 0 <= Players_126 <= 1 Integer
# 0 <= Players_127 <= 1 Integer
# 0 <= Players_128 <= 1 Integer
# 0 <= Players_129 <= 1 Integer
# 0 <= Players_13 <= 1 Integer
# 0 <= Players_130 <= 1 Integer
# 0 <= Players_131 <= 1 Integer
# 0 <= Players_132 <= 1 Integer
# 0 <= Players_133 <= 1 Integer
# 0 <= Players_134 <= 1 Integer
# 0 <= Players_135 <= 1 Integer
# 0 <= Players_136 <= 1 Integer
# 0 <= Players_137 <= 1 Integer
# 0 <= Players_138 <= 1 Integer
# 0 <= Players_139 <= 1 Integer
# 0 <= Players_14 <= 1 Integer
# 0 <= Players_140 <= 1 Integer
# 0 <= Players_141 <= 1 Integer
# 0 <= Players_142 <= 1 Integer
# 0 <= Players_143 <= 1 Integer
# 0 <= Players_144 <= 1 Integer
# 0 <= Players_145 <= 1 Integer
# 0 <= Players_146 <= 1 Integer
# 0 <= Players_147 <= 1 Integer
# 0 <= Players_148 <= 1 Integer
# 0 <= Players_149 <= 1 Integer
# 0 <= Players_15 <= 1 Integer
# 0 <= Players_150 <= 1 Integer
# 0 <= Players_151 <= 1 Integer
# 0 <= Players_152 <= 1 Integer
# 0 <= Players_153 <= 1 Integer
# 0 <= Players_154 <= 1 Integer
# 0 <= Players_155 <= 1 Integer
# 0 <= Players_156 <= 1 Integer
# 0 <= Players_157 <= 1 Integer
# 0 <= Players_158 <= 1 Integer
# 0 <= Players_159 <= 1 Integer
# 0 <= Players_16 <= 1 Integer
# 0 <= Players_160 <= 1 Integer
# 0 <= Players_161 <= 1 Integer
# 0 <= Players_162 <= 1 Integer
# 0 <= Players_163 <= 1 Integer
# 0 <= Players_164 <= 1 Integer
# 0 <= Players_165 <= 1 Integer
# 0 <= Players_166 <= 1 Integer
# 0 <= Players_167 <= 1 Integer
# 0 <= Players_168 <= 1 Integer
# 0 <= Players_169 <= 1 Integer
# 0 <= Players_17 <= 1 Integer
# 0 <= Players_170 <= 1 Integer
# 0 <= Players_171 <= 1 Integer
# 0 <= Players_172 <= 1 Integer
# 0 <= Players_173 <= 1 Integer
# 0 <= Players_174 <= 1 Integer
# 0 <= Players_175 <= 1 Integer
# 0 <= Players_176 <= 1 Integer
# 0 <= Players_177 <= 1 Integer
# 0 <= Players_178 <= 1 Integer
# 0 <= Players_18 <= 1 Integer
# 0 <= Players_19 <= 1 Integer
# 0 <= Players_2 <= 1 Integer
# 0 <= Players_20 <= 1 Integer
# 0 <= Players_21 <= 1 Integer
# 0 <= Players_22 <= 1 Integer
# 0 <= Players_23 <= 1 Integer
# 0 <= Players_24 <= 1 Integer
# 0 <= Players_25 <= 1 Integer
# 0 <= Players_26 <= 1 Integer
# 0 <= Players_27 <= 1 Integer
# 0 <= Players_28 <= 1 Integer
# 0 <= Players_29 <= 1 Integer
# 0 <= Players_3 <= 1 Integer
# 0 <= Players_30 <= 1 Integer
# 0 <= Players_31 <= 1 Integer
# 0 <= Players_32 <= 1 Integer
# 0 <= Players_33 <= 1 Integer
# 0 <= Players_34 <= 1 Integer
# 0 <= Players_35 <= 1 Integer
# 0 <= Players_36 <= 1 Integer
# 0 <= Players_37 <= 1 Integer
# 0 <= Players_38 <= 1 Integer
# 0 <= Players_39 <= 1 Integer
# 0 <= Players_4 <= 1 Integer
# 0 <= Players_40 <= 1 Integer
# 0 <= Players_41 <= 1 Integer
# 0 <= Players_42 <= 1 Integer
# 0 <= Players_43 <= 1 Integer
# 0 <= Players_44 <= 1 Integer
# 0 <= Players_45 <= 1 Integer
# 0 <= Players_46 <= 1 Integer
# 0 <= Players_47 <= 1 Integer
# 0 <= Players_48 <= 1 Integer
# 0 <= Players_49 <= 1 Integer
# 0 <= Players_5 <= 1 Integer
# 0 <= Players_50 <= 1 Integer
# 0 <= Players_51 <= 1 Integer
# 0 <= Players_52 <= 1 Integer
# 0 <= Players_53 <= 1 Integer
# 0 <= Players_54 <= 1 Integer
# 0 <= Players_55 <= 1 Integer
# 0 <= Players_56 <= 1 Integer
# 0 <= Players_57 <= 1 Integer
# 0 <= Players_58 <= 1 Integer
# 0 <= Players_59 <= 1 Integer
# 0 <= Players_6 <= 1 Integer
# 0 <= Players_60 <= 1 Integer
# 0 <= Players_61 <= 1 Integer
# 0 <= Players_62 <= 1 Integer
# 0 <= Players_63 <= 1 Integer
# 0 <= Players_64 <= 1 Integer
# 0 <= Players_65 <= 1 Integer
# 0 <= Players_66 <= 1 Integer
# 0 <= Players_67 <= 1 Integer
# 0 <= Players_68 <= 1 Integer
# 0 <= Players_69 <= 1 Integer
# 0 <= Players_7 <= 1 Integer
# 0 <= Players_70 <= 1 Integer
# 0 <= Players_71 <= 1 Integer
# 0 <= Players_72 <= 1 Integer
# 0 <= Players_73 <= 1 Integer
# 0 <= Players_74 <= 1 Integer
# 0 <= Players_75 <= 1 Integer
# 0 <= Players_76 <= 1 Integer
# 0 <= Players_77 <= 1 Integer
# 0 <= Players_78 <= 1 Integer
# 0 <= Players_79 <= 1 Integer
# 0 <= Players_8 <= 1 Integer
# 0 <= Players_80 <= 1 Integer
# 0 <= Players_81 <= 1 Integer
# 0 <= Players_82 <= 1 Integer
# 0 <= Players_83 <= 1 Integer
# 0 <= Players_84 <= 1 Integer
# 0 <= Players_85 <= 1 Integer
# 0 <= Players_86 <= 1 Integer
# 0 <= Players_87 <= 1 Integer
# 0 <= Players_88 <= 1 Integer
# 0 <= Players_89 <= 1 Integer
# 0 <= Players_9 <= 1 Integer
# 0 <= Players_90 <= 1 Integer
# 0 <= Players_91 <= 1 Integer
# 0 <= Players_92 <= 1 Integer
# 0 <= Players_93 <= 1 Integer
# 0 <= Players_94 <= 1 Integer
# 0 <= Players_95 <= 1 Integer
# 0 <= Players_96 <= 1 Integer
# 0 <= Players_97 <= 1 Integer
# 0 <= Players_98 <= 1 Integer
# 0 <= Players_99 <= 1 Integer

# %%
# positions
# constraint: 1 <= number of PG <= Max 3
pointguards = tuple(specificDate['Pos'] == 'PG')
problem += pulp.lpSum(playerInLineup[i] * pointguards[i] for i in numOfPlayers) >= 1
problem += pulp.lpSum(playerInLineup[i] * pointguards[i] for i in numOfPlayers) <= 3

# constraint: 1 <= number of SG <= Max 3
shootguards = tuple(specificDate['Pos'] == 'SG')
problem += pulp.lpSum(playerInLineup[i] * shootguards[i] for i in numOfPlayers) >= 1
problem += pulp.lpSum(playerInLineup[i] * shootguards[i] for i in numOfPlayers) <= 3

# constraint: 1 <= number of SF <= Max 3
smallforward = tuple(specificDate['Pos'] == 'SF')
problem += pulp.lpSum(smallforward[i] * playerInLineup[i] for i in numOfPlayers) >= 1
problem += pulp.lpSum(smallforward[i] * playerInLineup[i] for i in numOfPlayers) <= 3

# constraint: 1 <= number of PF <= Max 3
powerfoward = tuple(specificDate['Pos'] == 'PF')
problem += pulp.lpSum(powerfoward[i] * playerInLineup[i] for i in numOfPlayers) >= 1
problem += pulp.lpSum(powerfoward[i] * playerInLineup[i] for i in numOfPlayers) <= 3

# constraint: 1 <= number of C <= Max 2
centers = tuple(specificDate['Pos'] == 'C')
problem += pulp.lpSum(playerInLineup[i] * centers[i] for i in numOfPlayers) <= 2
problem += pulp.lpSum(playerInLineup[i] * centers[i] for i in numOfPlayers) >= 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-121-16ac1bdf88b0> in <module>
#       2 # constraint: 1 <= number of PG <= Max 3
#       3 pointguards = tuple(specificDate['Pos'] == 'PG')
# ----> 4 problem += pulp.lpSum(playerInLineup[i] * pointguards[i] for i in numOfPlayers) > 1
#       5 problem += pulp.lpSum(playerInLineup[i] * pointguards[i] for i in numOfPlayers) < 3
#       6
#
# TypeError: '>' not supported between instances of 'LpAffineExpression' and 'int'

# %%
# calculated predicted lineup
cost = 0
points = 0

predicted = set()
if problem.solve() == 1:
    for pos in range(len(numOfPlayers)):
        if playerInLineup[pos].value() == 1:
            name = playerNames[pos]
            predicted.add(name)
            cost += playerCosts[pos]
            points += playerPoints[pos]
            print (playerNames[pos], playerPositions[pos], playerCosts[pos],playerPoints[pos], teams[pos])
    print (cost, points)
else:
    print ('Error finding solution')
# Out:
# Knight_Brandon PG 7000 78 pho
# Westbrook_Russell PG 12200 72 okc
# Conley_Mike PG 6000 46 mem
# Ellis_Monta SG 5800 36 ind
# Leonard_Kawhi SF 8200 44 sas
# Ariza_Trevor SF 5500 38 hou
# Gibson_Taj PF 3600 38 chi
# Green_Jeff SF 3500 34 mem
# Okafor_Jahlil C 7200 40 phi
# 59000 426

# %%
# create dataframe of past perfect lineups
pastwinners = pandas.read_csv('../Scraping/NumberFire/numberFireBestTeam.csv')
# # strip '$' from Salary, convert to integer
pastwinners['Salary'] = pastwinners['Salary'].map(lambda ele: int(ele.replace('$', '')))

# %%
# convert date to alternative format to look up past winners
date = str(int(date))
day = date[6:8][1] if int(date[6:8]) < 10 else date[6:8]
month = date[4:6][1] if int(date[4:6]) < 10 else date[4:6]
year = date[2:4]
date = month + '-' + day + '-' + year

# %%
# calculate ideal lineup
ideal = set()
for name in pastwinners[pastwinners['Date'] == date]['PlayerName']:
    name = name.split()
    name = name[1] + ', ' + name[0]
    ideal.add(name)

cost = sum(pastwinners[pastwinners['Date'] == date]['Salary'])
points = sum(pastwinners[pastwinners['Date'] == date]['FP'])

print (pastwinners[pastwinners['Date'] == date].head(8))
    
print (cost, points)
# Out:
# Empty DataFrame
# Columns: [Date, PlayerName, Position, Salary, Pts, R, A, S, T, B, FP]
# Index: []
# 0 0

# %%
# load data frame to compare outputs
idealvspredicted = pandas.read_csv('../Data/idealversuspredicted.csv', index_col=0)
idealvspredicted = idealvspredicted.sort_values('Date').reset_index(drop=True)
idealvspredicted.head()
# Out:
#          Date  NumberFire Cost  NumberFire Points  Predicted Cost  Predicted Points
# 0  20151117.0            49900             377.00           49900            377.00
# 1  20151119.0            49700             330.75           49700            330.75
# 2  20151122.0            49200             375.25           49800            377.50
# 3  20151123.0            49000             386.00           49000            386.00
# 4  20151124.0            50000             351.50           50000            351.50

# %%
fig = plt.figure(figsize=(10,10))
pointDiff = idealvspredicted['Predicted Points'] - idealvspredicted['NumberFire Points']
pointDiff.plot.hist(alpha=0.5, bins=60)
plt.xlabel('Point Difference = Our Lineup\'s Fantasy Points - NumberFire\'s Lineup\'s Fantasy Points')

fig.savefig('lineuppointdiff.png', bbox_inches='tight')

# %%
print 'Above par: %2.2f%%' % (100.0 * sum(pointDiff > 0)/len(pointDiff))
print 'On par:    %2.2f%%' % (100.0 * sum(pointDiff == 0)/len(pointDiff))
print 'Below par: %2.2f%%' % (100.0 * sum(pointDiff < 0)/len(pointDiff))
# Out:
#   File "<ipython-input-120-d9537dfbda21>", line 1
#     print 'Above par: %2.2f%%' % (100.0 * sum(pointDiff > 0)/len(pointDiff))
#                              ^
# SyntaxError: invalid syntax
